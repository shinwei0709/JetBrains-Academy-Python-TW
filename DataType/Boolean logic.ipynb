# %% [markdown]
# 布林邏輯 (Boolean logic)
#
# 1.優先權Priority
#
# 從最高到最低對布林運算進行排序。
#
# Sort boolean operations from the highest priority to the lowest.
#
# not
# and
# or
#
# 2.邏輯運算Logical operations
#
# 在Python中，邏輯運算符and和or遵循短路評估規則。
#
# 這裡有兩個布林變量：
#
# In Python, logical operators and and or follow short-circuit evaluation rule.
#
# There are two boolean variables:

# %%
a = True
b = False

# %% [markdown]
# 選擇可以完全確定其值的表達式。
#
# Choose the expressions that should be evaluated fully to determine their value.
#
# Select one or more options from the list
#
# (a)a and b
#
# (b)b and a
#
# (c)not a or b
#
# (d)b or a
#
# (e)not a and b
#
# (f)a or b
#
#
#
# 3.布林值Boolean values
#
# 假設變量具有以下布林值：
#
# Assuming that variables have the following boolean values:

# %%
a = True
b = not a

# %% [markdown]
# 輸入表達式的計算結果：
#
# Enter the result of evaluating the expression:

# %%
not (a and b)

# %% [markdown]
# 4.布林表達式Boolean expression
#
#
# 以下表達式的布林值是多少？
#
# What will be the boolean value of the following expression? Write the result.

# %%
not None or 1

# %% [markdown]
# 5.XOR
#
# 異或（或簡稱為XOR）是二進制邏輯運算。僅當兩個參數都不同時才返回True（一個為True，另一個為False）
#
# Exclusive OR, or simply XOR, is a binary logical operation. It returns True only if both arguments are different (one is True, the other is False).
#
# ![image.png](attachment:image.png)
#
# 選擇與XOR閘於布林變量a和b具有相同結果的所有表達式（即，表達式為a XOR b）
#
# Select all the expressions that give the same result as applying XOR to the boolean variables a and b (that is, the expressions acting as a XOR b).
#
# Select one or more options from the list
#
# (a)not a or b
#
# (b)(a or b) and not (a and b)
#
# (c)(a and b) or not (a or b)
#
# (d)(a and not b) or (not a and b)
#
# (e)a and not b
