# %% [markdown]
# 命名變量（Naming variables）
#
# 1.最好的名字The best name
#
# 根據命名的原則，下列哪個名字是最佳的？
#
# Which of the following variable names is the best according to naming conventions?
#
# Select one option from the list
#
# (a)user_home_address
#
# (b)userhomeaddress
#
# (c)userHomeAddress
#
# (c)_uha
#
# 2.如何命名變量？How to name a variable?
#
# 請根據PEP8規定，選擇所有命名正確的變量
#
# Select all the correct variable names according to PEP8 code style convention.
#
# Select one or more options from the list
#
# (a)O
#
# (b)class_
#
# (c)int
#
# (d)correctAnswer
#
# (e)error_message
#
# 3.班級人數Number of people in the class
#
# 名稱number_of_people_in_the_class是一個非常長的變量名稱。縮短它的最佳方法是什麼？
#
# The name number_of_people_in_the_class is a very long name for a variable. What is the best way to shorten it?
#
# Select one option from the list
#
# (a)n_o_p
#
# (b)nopitc
#
# (c)n_of_people_inc
#
# (d)number_of_people
#
#
# 4.好名字Good names
#
# 以下是變量的列表：
#
# Here's a list of variables:

# %%
n = 10
model_score = 0.9875
client_name = "Bob"
colorOfTheShirt = "red"

# %% [markdown]
# 其中有些是根據規定命名的，有些不是
#
# 把正確的變量複製到程式裡
#
# Some of them are named according to naming conventions and best practices, others are not.
#
# Copy only the lines with those variables that have good names in your code.
#
# 5.珠穆朗瑪峰Everest
#
# 在你的程式中，你需要一個變量來儲存珠穆朗瑪峰的高度。裡面還有其他的山脈高度需要儲存，所以不能簡單的使用heght來存。變量的名稱應反映該值是常數的事實，並引用度量和對象。
#
# 該變量的最佳名稱是什麼？
#
# In your program, you need a variable to store the height of the mountain Everest (8, 848 m). There are other heights and other mountains in the program, so you cannot simply call it height . The name of the variable should reflect the fact that the value is constant and refer to the measure and the object.
#
# What would be an optimal name for that variable?
#
# Select one option from the list
#
# (a)the_height_of_everest_in_meters
#
# (b)height_of_everest
#
# (c)everest_height
#
# (d)MOUNTAIN_HEIGHT
#
# (e)mountain_everest
#
# (f)EVEREST_HEIGHT
